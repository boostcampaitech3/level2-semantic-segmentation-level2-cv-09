# %% [markdown]
# 라이브러리 호출

# %%
import argparse
import os
import os.path as osp
import shutil
import time
import warnings

import mmcv
import torch
from mmcv import Config
from mmcv.cnn.utils import revert_sync_batchnorm
from mmcv.parallel import MMDataParallel, MMDistributedDataParallel
from mmcv.runner import (get_dist_info, init_dist, load_checkpoint,
                         wrap_fp16_model)
from mmcv.utils import DictAction

from mmseg import digit_version
from mmseg.apis import multi_gpu_test, single_gpu_test
from mmseg.datasets import build_dataloader, build_dataset
from mmseg.models import build_segmentor
from mmseg.utils import setup_multi_processes

# %% [markdown]
# 모델 세팅

# %%
# config 파일과 work_dir, epoch(model)을 설정해주세요.
cfg = Config.fromfile('/opt/ml/input/code/models/mmsegmentation/convnext_config.py')
cfg.work_dir = '/opt/ml/input/code/mmsegmentation/work_dirs/convnext_config'
epoch = 'latest'


cfg.seed=2022
cfg.gpu_ids = [1]
cfg.model.train_cfg = None

# build dataset & dataloader
dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
        dataset,
        samples_per_gpu=1,
        workers_per_gpu=cfg.data.workers_per_gpu,
        dist=False,
        shuffle=False)

# checkpoint path
checkpoint_path = os.path.join(cfg.work_dir, f'{epoch}.pth')

model = build_segmentor(cfg.model, test_cfg=cfg.get('test_cfg')) # build detector
checkpoint = load_checkpoint(model, checkpoint_path, map_location='cpu') # ckpt load

model.CLASSES = dataset.CLASSES
model = MMDataParallel(model.cuda(), device_ids=[0])

# %% [markdown]
# Inference

# %%
output = single_gpu_test(model, data_loader) # output 계산
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 624/624, 12.8 task/s, elapsed: 49s, ETA:     0s

# %% [markdown]
# Make Submission

# %%
import json
import pandas as pd

# 저장 위치를 설정하세요.
save_dir = "/opt/ml/input/baseline/submission/jdu_test.csv"

with open("/opt/ml/input/data/test.json", "r") as f:
    test = json.load(f)

# sample_submisson.csv 열기
submission = pd.read_csv('/opt/ml/input/baseline/submission/sample_submission.csv', index_col=None)

for id, out in zip(test['images'], output):
    submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))}, 
                                   ignore_index=True)
# submission.csv로 저장
submission.to_csv(save_dir, index=False)
# Out:
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
# /tmp/ipykernel_12987/1511605894.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   submission = submission.append({"image_id" : id['file_name'], "PredictionString" : " ".join(map(str, out[::2,::2].flatten().tolist()))},
